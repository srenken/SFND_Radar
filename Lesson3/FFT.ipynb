# %% [markdown]
# ### Lesson 3: Range-Doppler Estimation
#
# #### Fast Fourier Transform (FFT) Exercise Solution

# %%
! pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (1.12.0)
# Requirement already satisfied: matplotlib in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (3.8.2)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from scipy->-r requirements.txt (line 1)) (1.26.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (6.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/sebastian/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 2)) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.15.0)

# %%
# import packages

import numpy as np 
import matplotlib.pyplot as plt
from scipy.fftpack import fft, fft2, fftshift

# %%
Fs = 1000  # sampling frequency
T = 1 / Fs  # sampling period
L = 1500  # length of signal (1500 ms)
t = np.arange(0, L) * T  # time vector

# TODO: Form a signal containing a 77 Hz sinusoid of amplitude 0.7 
# and a 43Hz sinusoid of amplitude 2.
#S = None
#S = 0.7 * np.sin(2*np.pi * 77 * t) + 2 * np.sin(2*np.pi * 43 * t)
S = 0.7*np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)

# Corrupt the signal with noise
X = S + 2*np.random.normal(0,1,len(S))
#X = S

# Plot the noise signal (X(t)) in time domain
# Note: It is difficult to identiy the frequency components by looking
# at the signal X(t)
plt.plot(X[1:50])
plt.title('Signal Corrupted with Zero-Mean Random Noise')
plt.xlabel('t (milliseconds)')
plt.ylabel('X(t)')
plt.show()

# %%
# TODO: Compute the Fourier transform of the signal
S_fft = fft(X)

# TODO : Compute the two-sided spectrum P2. 
# Then compute the single-sided spectrum P1 based on P2 
# and the even-valued signal length L.
P2 = abs(S_fft/L)
P1 = P2[0:int(L/2)]

f = Fs*(np.arange(0,L/2))/L;
#f = Fs*(np.arange(0,L))/L

fig, ax = plt.subplots(1)
ax.plot(f, P1)
plt.title('Single-Sided Amplitude Spectrum of X(t)')
plt.xlabel('f (Hz)')
plt.ylabel('|P1(f)|')
# Out:
# Text(0, 0.5, '|P1(f)|')
